# %% [markdown]
# # CP213: Model Solutions for Tutorial Notebook 4

# %% [markdown]
# ## Question 1

# %% [markdown]
# The amount of work $dW$ that is extracted by an engine from a given
# amount of heat $dQ$ fed to it is
# \begin{align*}
# dW = \eta\, dQ
# \end{align*}
# where $\eta$ is the engine efficiency.  The maximum theoretical
# efficiency of an engine is given by the Carnot efficiency
# \begin{align*}
#   \eta_C = 1 - \frac{T_C}{T_H}
# \end{align*}
# where $T_H$ is the temperature at which the heat is absorbed by the
# engine, and $T_C$ is the temperature at which the heat is rejected.
#
# 1. Determine the maximum amount of work that can be extracted from
#   a $250\,{\rm mL}$ cup of hot water initially at $60^\circ{\rm C}$,
#   if the surrounding environment is at a fixed temperature of
#   $20^\circ{\rm C}$.  Note that the density of water is approximately
#   $1\,{\rm g\,mL}^{-1}$, and its heat capacity is approximately
#   $4.2\,{\rm J\,g^{-1}\,K^{-1}}$.
#
# 2. Determine the maximum amount of work that can be extracted from
#   a $250\,{\rm g}$ block of ice initially at $0^\circ{\rm C}$, if the
#   surrounding environment is at a fixed temperature of
#   $20^\circ{\rm C}$.  Note that the heat capacity is approximately
#   $2.1\,{\rm J\,g^{-1}\,K}^{-1}$, and the heat of fusion of water is
#   $334\,{\rm J\,g}^{-1}$.

# %% [markdown]
# ## Model solution for Q1

# %% [markdown]
# ### Part 1
#
# The work $dW$ that can be produced by an engine from heat $dQ_H$
# supplied to it is given by
# \begin{align*}
#   dW &= \eta dQ_H
# \end{align*}
# where $\eta$ is the efficiency of the engine.  For a Carnot engine,
# the efficiency is given by $\eta=1-T_C/T_H$, where $T_H$ is the
# temperature at which heat is supplied to the engine, and $T_C$ is the
# temperature at which heat is rejected from the engine.  For this
# problem, the engine receives heat at $T_H$, the temperature of the
# water in the cup, and rejects heat to the surrounding air, which is at
# temperature $T_0$.
#
# When heat $dQ_H$ is extracted from the cup of water, its temperature
# decreases by an amount $dT_H$, given by the relation
# \begin{align*}
#   dQ_H &= -mC dT_H
# \end{align*}
# where $m$ is the mass of water in the cup, and $C$ is the heat
# capacity of water.
#
# Combining these facts, we can determine the total amount of work that
# can be extracted from the hot cup of water:
# \begin{align*}
#   dW &= \left(1-\frac{T_0}{T_H}\right)(-mC)dT_H
#   \\
#   W &= \int_{T_{H1}}^{T_0} \left(1-\frac{T_0}{T_H}\right)(-mC)dT_H
#   \\
#   &= -mC \left[T_H-T_0\ln|T_H|\right]_{T_{H1}}^{T_0}
#   \\
#   &= -mC \left[T_0-T_{H1}-T_0\ln\frac{T_0}{T_{H1}}\right]
#   \\
#   &= mC \left[(T_{H1}-T_0)-T_0\ln\frac{T_{H1}}{T_0}\right]
# .
# \end{align*}

# %%
V = 250.0   # mL
rho = 1.0   # g mL^{-1}
m = rho * V # g
C = 4.2     # J g^{-1} K^{-1}
TH1 = 60.0+273.15
T0 = 20.0+273.15

import numpy as np


W = m*C*(TH1-T0-T0*np.log(TH1/T0))
print(f'work = {W} J')

# %% [markdown]
# ### Part 2
#
# For this problem, the heat supplied to the engine is at the
# temperature $T_0$ of the surrounding air, and it is rejected at the
# temperature of the ice/water.  While the ice is melting, its
# temperature will remain at a temperature of $0^\circ{\rm C}$.  When
# the ice is completely melted, the melt water will gradually increase
# in temperature until it reaches $T_0$.
#
# The work is given by
# \begin{align*}
#   dW
#   &= \eta dQ_H
#   \\
#   &= \eta (dW + dQ_C)
#   \\
#   &= \frac{\eta}{1-\eta} dQ_C
#   \\
#   &= \left(\frac{T_H}{T_C}-1\right) {dQ_C}
# \end{align*}
# where we have used the energy balance around the engine $dQ_H=dW +dQ_C$.
#
# We will divide the process into two stages.  The first is the complete
# melting of the ice, and the second stage is the heating of the melt
# water from $0^\circ{\rm C}$ to room temperature $T_0$.  The work
# extracted in the first stage will be denoted by $\Delta W_1$, and the
# work extracted in the second stage will be denoted by $\Delta W_2$.
#
# In the first stage, $T_H=T_0$ and $T_C=T_m=0^\circ{\rm C}$, the
# melting temperature of ice.  The heat rejected by engine is the
# enthalpy of melting of the ice.  This leads to
# \begin{align*}
# \Delta W_1 &=  \left(\frac{T_0}{T_m}-1\right) m\Delta H
# \end{align*}
#
# In the second stage, $T_H=T_0$, and $T_C$ changes with time.  The
# received by the melt water is $dQ_C=mCdT_C$.  This leads to
# \begin{align*}
#   dW_2
#   &= \left(\frac{T_0}{T_C}-1\right) mC dT_C
#   \\
#   \Delta W_2
#   &= \int_{T_m}^{T_0} \left(\frac{T_0}{T_C}-1\right) mC dT_C
#   \\
#   &= mC \left[T_0 \ln T_C - T_C\right]_{T_m}^{T_0}
#   \\
#   &= mC \left[T_0 \ln\frac{T_0}{T_m}-(T_0-T_m)\right]
# \end{align*}
# The total amount of work extracted is
# \begin{align*}
#   \Delta W
#   &= \Delta W_1 + \Delta W_2
#     .
# \end{align*}

# %%
DeltaH = 334.0 # J g^{-1}
Tm = 273.15    # K
m = 250.0 # mass of ice / g
C = 4.2 # J g^{-1} K^{-1}

DeltaW1 = (T0/Tm-1.0) * m * DeltaH
DeltaW2 = m*C*(T0*np.log(T0/Tm)-(T0-Tm))
W = DeltaW1 + DeltaW2

print(f'work = {W} J')

# %% [markdown]
# ## Question 2

# %% [markdown]
# The heat flux $q$ (heat flow per unit surface area) from the surface
# of a body can be described by Newton's law of cooling
# \begin{align*}
#   q &= h(T-T_\infty)
# ,
# \end{align*}
# where $T$ is the temperature of the body, $T_\infty$ is the
# surrounding temperature, and $h$ is the heat transfer coefficient.
#
#
# 1. Determine how the temperature of a $250\,{\rm mL}$ cup of water
#   initially at $60^\circ{\rm C}$ decreases with time if the
#   surrounding environment is at a fixed temperature of
#   $20^\circ{\rm C}$.  Assume that the heat transfer coefficient
#   $h=2\,{\rm W\,m^{-2}\,K^{-1}}$ and the area for heat transfer
#   $A=50\,{\rm cm}^2$.  Note that the density of water is approximately
#   $1\,{\rm g\,mL}^{-1}$, and its heat capacity is approximately
#   $4.2\,{\rm J\,g^{-1}\,K^{-1}}$.
#
# 2. If a Carnot engine is used to extract work from the hot cup of
#   water, determine how the power output of the engine varies with
#   time.  Assume that the values of $h$ and $A$ remain the same as
#   before.

# %% [markdown]
# ## Model solution for Q2

# %% [markdown]
# ### Part 1
#
# We take the control volume for the energy balance to be the cup of water.  The accumulation of energy $U$ in the cup of water is
# \begin{align*}
# \frac{dU}{dt}
# \end{align*}t/
# We note that the change in energy of the water is related to the temperature $T$ of the water through
# \begin{align*}
# dU = m C dT,
# \end{align*}
# where $m$ is the mass of water in the cup, and $C$ is the heat capacity.  Dividing both sides by an increment in time, we find
# an expression for the accumulation of energy in terms of the temperature of the water
# \begin{align*}
# \frac{dU}{dt} &= mC\frac{dT}{dt}
# .
# \end{align*}
#
# Energy flows out of the cup of water due to convection, which is given by Newton's law of cooling.  The rate of outflow of energy is equal to
# \begin{align*}
# hA(T-T_{\infty})
# \end{align*}
# where $A$ is the surface area for heat transfer.
#
# The energy balance is then
# \begin{align*}
# mC\frac{dT}{dt} &= - hA(T-T_{\infty}).
# \end{align*}
# Note the negative sign in front of the convection term, which reflects the fact that outflow of energy causes the temperature of the water in the cup to decrease.
#
# We can directly solve this equation by isolating variables.  We move all terms involveing the temperature to the left side of the equation and all terms involving time to the right side of the equation.
# \begin{align*}
# mC\frac{dT}{T-T_{\infty}} &= - hAdt.
# \end{align*}
# Integrating, both sides we find
# \begin{align*}
# mC\ln(T-T_{\infty}) &= - hAt + B
# \end{align*}
# where $B$ is an integration constant.  We can find the value of the integration constant through use of the initial condition $T=T_0$ at $t=0$, where $T_0=60^\circ{\rm C}$.
# \begin{align*}
# mC\ln(T_0-T_{\infty}) &= - hA(0) + B
# \\
# mC\ln(T_0-T_{\infty}) &= B.
# \end{align*}
# Substituting this back into our original solution, we arrive at:
# \begin{align*}
# mC\ln(T-T_{\infty}) &= - hAt + B
# = - hAt + mC\ln(T_0-T_{\infty})
# \\
# mC\ln\frac{T-T_{\infty}}{T_0-T_\infty}  &= -hAt
# \\
# T &= T_\infty + (T_0-T_\infty)e^{-t/\tau},
# \end{align*}
# where $\tau=mC/(hA)$.

# %%
C = 4.2 # J g^{-1} K^{-1}
m = 250.0  # g
A = 50.0 * 1.0e-4 # m^2
h = 2.0 # W m^{-2} K^{-1}
T0 = 60.0
Tinf = 20.0

tau = m*C/(h*A)
print(f'tau = {tau} s')
print(f'tau = {tau/3600.0} h')


import pylab as plt
import numpy as np

t_data = np.arange(0.0, tau*10.0)
T_data = [Tinf + (T0-Tinf)*np.exp(-t/tau) for t in t_data]

plt.plot(t_data, T_data)
plt.xlabel(r'time / seconds')
plt.ylabel(r'temperature / $^\circ{\rm C}$')
plt.show()

# %% [markdown]
# ### Part 2
#
# If we redirect the heat flow out of the water through a Carnot engine, we can generate work.  Not all of this heat can be transformed to work, but a portion $\eta$, equal to the efficiency of the engine, can be:
# \begin{align*}
# dW &= \eta dQ = -\eta dU = -\eta m C dT
# \end{align*}
# For a Carnot engine, the efficiency is given by
# \begin{align*}
# \eta &= 1 - \frac{T_C}{T_H}
# \end{align*}
# where $T_C$ is the temperature of the heat sink, and $T_H$ is the temperature of the heat source.  In this case, the heat sink is the environment surrounding the cup, which has a temperature $T_\infty$, and the heat source is the water in the cup, which has a temperature $T$, which varies with time.  This gives
# \begin{align*}
# dW &= -\Bigg(1-\frac{T_\infty}{T}\Bigg) m C dT
# \end{align*}
#
# The power generated by the engine is simple the work produced by it in an interval of time, which can be obtained simply by dividing both sides of the above equation by $dt$
# \begin{align*}
# \frac{dW}{dt} &= -\Bigg(1-\frac{T_\infty}{T}\Bigg) m C \frac{dT}{dt}
# \end{align*}
# This gives us the power output of the enging in terms of the temperature of the water in the cup, which we know from the previous problem.
#
# We note that
# \begin{align*}
# T(t) &= T_\infty + (T_0-T_\infty)e^{-t/\tau}
# \\
# \frac{dT}{dt}
# &= - \frac{(T_0-T_\infty)}{\tau}e^{-t/\tau}
# \end{align*}
# therefore, we have
# \begin{align*}
# \frac{dW}{dt} &= -\Bigg(1-\frac{T_\infty}{T}\Bigg) m C \frac{dT}{dt}
# \\
# &= \Bigg(1-\frac{T_\infty}{T}\Bigg)
# hA(T-T_\infty)
# \end{align*}

# %%
dTdt_data = [-(T0-Tinf)/tau*np.exp(-t/tau) for t in t_data]

power = [(1.0-(Tinf+273.15)/(T+273.15))*h*A*(T-Tinf) for T in T_data]

plt.plot(t_data, power)
plt.xlabel('time / seconds')
plt.ylabel('power / W')

plt.show()

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Part 1
#
# Flywheels can be used to create mechanical batteries:
# - [The Mechanical Battery Explained - A Flywheel Comeback?](https://www.youtube.com/watch?v=8X2U7bDNcPM)
# - [Flywheel Battery](https://www.youtube.com/watch?v=yhu3s1ut3wM)
# - [The Mechanical Battery](https://www.youtube.com/watch?v=_QLEERYS5C8)
#
# We want to create a mechanical battery which stores energy in the form
# of the rotational kinetic energy of a disk.  Determine kinetic energy
# of a solid disk with radius $R$ and thickness $H$ that is spinning
# at an angular velocity $\dot{\theta}$.  Assume that the disk is made of
# a material of density $\rho$.
#
# Recall that the velocity of a point a distance $r$ from the center of
# rotation is $v=\dot{\theta} r$.  The kinetic energy $E_{\rm kin}$ of
# an object of mass $m$ moving at speed $v$ is given by
# \begin{align*}
# E_{\rm kin}
# &= \frac{1}{2} m v^2
# .
# \end{align*}

# %% [markdown]
# ### Part 2
#
# We want to try to create a kinetic energy regeneration system for a
# bicycle, like in [Flywheel Bike KERS](https://www.youtube.com/watch?v=gahKxbwUcYw).
#
# Estimate the energy required to accelerate a person and his/her
# bicycle from rest to a speed of $10\,{\rm mph}$.  Assuming that the
# flywheel is a solid steel disk with a radius of $15\,{\rm cm}$ and a
# thickness of $1\,{\rm cm}$, what is the minimal theoretical rotational
# speed of the disk, in rpm, required accelerate the bicycle?

# %% [markdown]
# ## Model solution for Q3

# %% [markdown]
# ### Part 1
#
# To solve this problem, we divide the rotating disk into rings with a
# difference between the outer radius and inner radius given by $\Delta
# r$.  If $\Delta r$ is sufficiently small, we can consider that the
# speed of the material in the ring to be approximately the same.
#
# Consider a thin ring of inner diameter $r$ and outer diameter
# $r+\Delta r$.  The speed of the inner part of the ring is
# $v(r)=r\dot{\theta}$.  We assume that all of the ring has this
# velocity.  The mass of this ring is approximately $\Delta m\approx\rho
# 2\pi r\Delta r H$.  The kinetic energy $\Delta E_{\rm kin}$ of this
# thin ring is:
# \begin{align*}
# \Delta E_{\rm kin}
# &\approx \frac{1}{2} v^{2}(r) \Delta m
# \\
# &\approx \frac{1}{2} (r\dot{\theta})^2
# \rho 2\pi r\Delta r H
# \\
# &\approx  \rho H  \pi \dot{\theta}^2
#  r^3 \Delta r
# .
# \end{align*}
# To get the kinetic energy of the entire disk, we need to sum the
# kinetic energy of all the individual rings.  This sum becomes an
# integral in the limit $\Delta r\to0$:
# \begin{align*}
# E &= \int_0^R \rho H \pi \dot{\theta}^{2}  r^{3} dr
# \\
# &= \rho H \pi \dot{\theta}^{2}  \left.\frac{r^{4}}{4} \right|_0^R
# \\
# &= \rho H \pi \dot{\theta}^{2}  \frac{R^{4}}{4}
# .
# \end{align*}

# %% [markdown]
# ### Part 2
#
# We assume that the person is approximately $70\,{\rm kg}$, and from the site https://bicycleuniverse.com/how-much-does-bike-weigh/, we can estimate the mass of the bicycle to be about $20\,{\rm lbs}$.  We then find:

# %%
import numpy as np

v_mph = 10.0
v = v_mph / 3600.0 * 1609.34

m_person = 70.0
m_bicycle = 20.0 * 0.453592
m = m_person + m_bicycle

E = 0.5*m*v**2

print(f'speed = {v} m s^-1')
print(f'required energy = {E} J')



#rho = 2700.0 # density of aluminum / kg m^{-3}
rho = 8050.0 # density of steel / kg m^{-3}
#R = 1   # flywheel radius / m
R = 0.15 #
H = 0.01 # flywheel thickness / m

dot_theta = (E / (0.25*rho*H*np.pi*R**4))**0.5

rpm = dot_theta * 60.0 / (2.0*np.pi )
print(dot_theta)
print(f'angular speed of the flywheel: {rpm} rpm')

# %% [markdown]
# ## Question 4

# %% [markdown]
# Evaluate the following integrals analytically (possibly with help from
# an integral table) and using sympy:
#
# 1. $\displaystyle
# \int \frac{dx}{\sqrt{2-3x}}
# $
#
# 2. $\displaystyle
# \int \frac{dx}{\sqrt{3x^2-2}}
# $
#
# 3. $\displaystyle
# \int \frac{dx}{x^2\sqrt{x^2-2}}
# $
#
# 4. $\displaystyle
# \int dx\,\sqrt{x^2-2}
# $
#
# 5. $\displaystyle
# \int \frac{dx}{x^2+4x+3}
# $

# %% [markdown]
# ## Model solution for Q4

# %% [markdown]
# ### Part 1
#
# Making the substitution $y=2-3x$, we find $x=(2-y)/3$,  $dx=-dy/3$,
# and
# \begin{align*}
# \int \frac{dx}{\sqrt{2-3x}}
# &= \int \frac{-dy/3}{y^{1/2}}
# = - \frac{2}{3} y ^{1/2} + C
# \end{align*}
# Re-expressing this in terms of the variable $x$, we find
# \begin{align*}
# \int \frac{dx}{\sqrt{2-3x}}
# = - \frac{2}{3} \sqrt{2-3x} + C
# \end{align*}

# %%
from sympy import *

x = symbols('x')


I = integrate(1/sqrt(2-3*x), x)
print(I)

# %% [markdown]
# ### Part 2
#
# The form of the integrand suggests a trigonometric substitution.  If
# we set
# \begin{align*}
#   x
#   &= \frac{\sqrt{2/3}}{\cos\theta}
#   \\
#   dx
#   &= \frac{\sqrt{2/3}}{\cos^2\theta}\sin\theta d\theta
#     = \sqrt{2/3}\frac{\sin\theta d\theta}{\cos^2\theta}
#        .
# \end{align*}
# We then find
# \begin{align*}
#   \int \frac{dx}{\sqrt{3x^2-2}}
#   &= \int \sqrt{2/3}\frac{\sin\theta d\theta}{\cos^2\theta}
#     \frac{1}{\sqrt{2/\cos^2\theta-2}}
#   \\
#   &= \frac{1}{\sqrt{3}}\int \frac{\sin\theta d\theta}{\cos^2\theta}
#     \frac{\cos\theta}{\sqrt{1-\cos^2\theta}}
#   \\
#   &= \frac{1}{\sqrt{3}} \int \frac{d\theta}{\cos\theta}
#     = \frac{1}{\sqrt{3}} \int \frac{\cos\theta d\theta}{\cos^2\theta}
#     = \frac{1}{\sqrt{3}} \int \frac{\cos\theta d\theta}{1-\sin^2\theta}
#   \\
#   &= \frac{1}{\sqrt{3}} \int \cos\theta\,d\theta\,
#     \frac{1}{2}
#     \Bigg[
#     \frac{1}{1+\sin\theta} + \frac{1}{1-\sin\theta}
#     \Bigg]
#   \\
#   &= \frac{1}{2\sqrt{3}}
#     \Bigg[\ln(1+\sin\theta) - \ln(1-\sin\theta)
#     \Bigg] + C'
#   \\
#    &= \frac{1}{2\sqrt{3}}\ln\frac{1+\sin\theta}{1-\sin\theta} +C'
#   \\
#   &= \frac{1}{2\sqrt{3}}\ln\frac{(1+\sin\theta)^2}{1-\sin^2\theta} +C'
#     = \frac{1}{2\sqrt{3}}\ln\frac{(1+\sin\theta)^2}{\cos^2\theta} +C
#   \\
#   &= \frac{1}{2\sqrt{3}}\ln\frac{[1+\sqrt{1-2/(3x^2)}]^2}{2/(3x^2)}
#     +C'
#   \\
#   &= \frac{1}{2\sqrt{3}}\ln\frac{[3x+\sqrt{9x^2-6}]^2}{6}
#     +C'
#   \\
#   &= \frac{1}{\sqrt{3}}\ln(3x+\sqrt{9x^2-6})
#     + C
# \end{align*}

# %%
I = integrate(1/sqrt(3*x**2-2), x)
print(I)

# %% [markdown]
# ### Part 3
#
# The form of the integrand suggests a trigonometric substitution.  If
# we set $x=\sqrt{2}/\cos\theta$, then
# \begin{align*}
#   dx
#   &= \frac{\sqrt{2}}{\cos^2\theta}\sin\theta d\theta
#     = \sqrt{2}\frac{\sin\theta d\theta}{\cos^2\theta}
#        .
# \end{align*}
# We then find
# \begin{align*}
#   \int \frac{dx}{x^2\sqrt{x^2-2}}
#   &= \int \sqrt{2}\frac{\sin\theta d\theta}{\cos^2\theta}\,
#     \frac{1}{2/\cos^2\theta}\frac{1}{\sqrt{2/\cos^2\theta-2}}
#   \\
#     &= \frac{1}{2}\int \frac{\sin\theta d\theta}{\sqrt{1/\cos^2\theta-1}}
#   \\
#   &= \frac{1}{2}\int
#     \frac{\cos\theta\sin\theta d\theta}{\sqrt{1-\cos^2\theta}}
#     = \frac{1}{2}\int\cos\theta d\theta
#   \\
#   &= \frac{1}{2}\sin\theta + C
#     = \frac{1}{2}\sqrt{1-\cos^2\theta} + C
#   \\
#   &= \frac{1}{2}\sqrt{1-2/x^2} + C
#   \\
#   &= \frac{\sqrt{x^2-2}}{2x} + C
# \end{align*}

# %%
I = integrate(1/x**2/sqrt(x**2-2), x)
print(I)

# %% [markdown]
# ### Part 4
#
# $\displaystyle
# \int dx\,\sqrt{x^2-2}
# =   \frac{x}{2}\sqrt{x^2-2} - \ln(2x+2\sqrt{x^2-2})
#   + C
# $

# %%
I = integrate(sqrt(x**2-2), x)
print(I)

# %% [markdown]
# ### Part 5
#
# This integral can be performed with the help of a partial fractions decomposition of the integrand.  We note that the denominator can be factored as
# \begin{align*}
# x^2+4x+3 = (x+3)(x+1).
# \end{align*}
# This allows us to decompose the integrand as
# \begin{align*}
# \frac{1}{x^2+4x+3}
# = \frac{1}{2}\Bigg[\frac{1}{x+1} - \frac{1}{x+3}\Bigg]
# \end{align*}
#
# \begin{align*}
# \int \frac{dx}{x^2+4x+3}
# &= \int \frac{1}{2}\Bigg[\frac{1}{x+1} - \frac{1}{x+3}\Bigg]
# \\
# &= \frac{1}{2} \Bigg[\ln(x+1) - \ln(x+3)\Bigg] + C
# \\
# &= \frac{1}{2}\ln\frac{x+1}{x+3} + C
# \end{align*}

# %%
I = integrate(1/(x**2+4*x+3), x)
print(I)
