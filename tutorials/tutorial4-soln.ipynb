# %% [markdown]
# # CP213: Tutorial Notebook Week 4

# %% [markdown]
# ## Question 1
#
# Consider a block of mass $m$ with a trapezoidal cross-section that has
# a base of length $L$ as shown in the figure below.  This block serves
# as a dam which holds back a body of water in a channel of width $W$.
# How high can the water level be before the block begins to slide?
# Write the answer in terms of the atmospheric pressure $p_0$, the
# acceleration due to gravity $g$, the density $\rho$ of water, the mass
# $m$ of the block, the length of its base $L$, the angle $\theta$, and
# the friction coefficient $\mu$ between the block and the ground.
#
#
# ![dam](./dam.png)

# %% [markdown]
# ## Model solutions for Q1
#
# The downward pressure force of the water on a small section of the
# block of height $dy$ located at a height $y$ from the bottom of the
# block is given by
# \begin{align*}
# dF_y &= - p(y) \frac{W dy}{\sin\theta} \cos\theta
# \\
# &= - [p_0 + \rho g(H-y)] \frac{W dy}{\sin\theta} \cos\theta
# .
# \end{align*}
# By integrating this force and including the force due to the
# atmospheric pressure, we find that the total pressure force in the
# $y$-direction is
# \begin{align*}
# F_y &= - \int_0^H [p_0 + \rho g(H-y)] \frac{W dy}{\sin\theta} \cos\theta
# - p_0 (L-H\cot\theta)W
# \\
# &= - \left[(p_0 + \rho gH)y-\rho g\frac{y^2}{2}\right]_0^H W\cot\theta
# - p_0 (L-H\cot\theta)W
# \\
# &= - \left[(p_0 + \rho gH)H-\rho g\frac{H^2}{2}\right] W\cot\theta
# - p_0 (L-H\cot\theta)W
# \\
# &= - \left[p_0 + \rho g\frac{H}{2}\right] WH \cot\theta
# - p_0 (L-H\cot\theta)W
# \\
# &= - \rho g\frac{WH^2}{2}\cot\theta
# - p_0 LW
# .
# \end{align*}
#
# The force in the $x$-direction due to the pressure on a small section
# of the block of height $dy$ located at a height $y$ from the bottom of
# the block is given by
# \begin{align*}
# dF_x &= p(y) \frac{W dy}{\sin\theta} \sin\theta - p_0 Wdy
# \\
# &= [p_0 + \rho g(H-y)] \frac{W dy}{\sin\theta} \sin\theta  - p_0 Wdy
# \\
# &= [p_0 + \rho g(H-y)] W dy  - p_0 Wdy
# .
# \end{align*}
# By integrating this force across the entire surface of the block, we
# find the net force in the $x$-direction is
# \begin{align*}
# F_x &= \int_0^H [p_0 + \rho g(H-y)] W dy  - \int_0^H p_0 Wdy
# \\
# &= \left[(p_0 + \rho g H)y -\rho g \frac{y^2}{2}) - p_0 \right]_0^H W
# \\
# &= \left[(p_0 + \rho g H)H -\rho g \frac{H^2}{2}) - p_0H \right] W
# \\
# &= \rho g \frac{WH^2}{2}
# .
# \end{align*}
#
# The block will move when the net pressure force pushing the block to
# the right is becomes greater than the friction force:
# \begin{align*}
# \rho g \frac{WH^2}{2}
# &= \mu\left[mg + \rho g\frac{WH^2}{2}\cot\theta + p_0 LW\right]
# \\
# \rho g \frac{H^2}{2}
# &= \mu\left[\frac{mg}{W} + \rho g\frac{H^2}{2}\cot\theta + p_0 L\right]
# \\
# \rho g \frac{H^2}{2}(1-\mu \cot\theta) &= \mu \left(\frac{mg}{W}+p_0 L\right)
# \\
# H &= \left[\frac{2\mu (mg/W+p_0 L)}{\rho g (1-\mu \cot\theta)}\right]^{1/2}
# .
# \end{align*}

# %% [markdown]
# ## Question 2
#
# A Ferrari 360 Modena (see the figure below) has a
# $\dot{W}=410\,{\rm hp}$ engine and mass of $m=1450\,{\rm kg}$.  The
# force $F_e$ that propels the car forward is provided by the engine,
# and the magnitude of that force is directly related to the power it
# supplies.  Recall that when a force acts over a distance, it performs
# work.  That is, if a force ${\bf F}$ acts over a small displacement
# $d{\bf x}$, then the work performed $dW$ is
# \begin{equation*}
# \label{eq:work}
# dW = {\bf F}\cdot d{\bf x}
# .
# \end{equation*}
# Remember that power is the rate at which work is performed; that is,
# it is the work per unit time.  By dividing both sides of
# the above equation by the interval of time $dt$ over which the
# displacement occurred, we find:
# \begin{equation*}
# \frac{dW}{dt} = {\bf F}\cdot \frac{d{\bf x}}{dt}
# .
# \end{equation*}
# Using the fact that displacement per unit time is just the velocity,
# we find:
# \begin{equation*}
# \label{eq:power}
# \dot{W} = {\bf F}\cdot{\bf v}
# .
# \end{equation*}
# So, power (or the rate at which work is performed) is equal to the
# force times velocity.
#
# If the engine outputs a power $\dot{W}$, then the force $F_e$ it
# supplies is:
# \begin{equation*}
# F_e = \frac{\dot{W}}{v}
# \end{equation*}
# where $v$ is the speed of the car.
#
# At low speeds, one of the main sources of friction acting on a car is
# rolling friction, which acting in a direction opposing the motion of
# the car.  The magnitude of this friction $F_r$ is given by:
# \begin{equation*}
# F_r = -\mu_r m g
# \end{equation*}
# where $\mu_r$ is the coefficient of rolling friction.  The value of
# $\mu_r$ depends on the surface the car is traveling over; for a car on
# asphalt, $\mu_r\approx0.03$.
#
# At higher speeds, air resistance becomes increasingly important.  The
# drag force $F_d$ on a moving object due to air resistance is described
# by
# \begin{align*}
#   F_d &= C_d A \frac{1}{2}\rho v^2
# %  C_d &= \frac{F_d/A}{\rho v^2/2}
# \end{align*}
# where $C_d$ is the drag coefficient (a dimensionless quantity
# dependent on the shape of the object), $A$ is a reference area
# (typically the projected area of the object), and $\rho$ is the
# density of the fluid.  The body of the car has a constant drag
# coefficient $C_d = 0.34$, based on a frontal reference area of
# $A=2.03\,{\rm m}^2$.  Assume the density of air is
# $1.225\,{\rm kg\,m}^{-3}$.
#
# ![](./car.png)
#
#
# 1. By considering the forces acting on the vehicle show that the
# top speed of the car can be expressed by:
# \begin{align*}
# \dot{W} &= \left[\mu m g + \frac{1}{2} C_d A \rho v^2\right] v
# \end{align*}
# and estimate the top speed.  This may require use of numerical method.
# Can you simplify the final equation? [$v=86\,{\rm m\,s}^{-1}$]
#
# 2. How long will it take the car to increase the speed from $0$ to
#   $60$\,mph?  Hint: Consider the net force acting on the car to set up
#   the equation:
# \begin{align*}
# m \frac{dv}{dt} &= - F_f - F_d + F_e,
# \end{align*}
# then arrange it for and use the trapezoid rule to solve this
# problem. [$t=1.77\,{\rm s}$]
#
#
# Hints:
# - $1\,{\rm hp}=745.7\,{\rm W}$
# - $1\,{\rm m\,s}^{-1}=2.24\,{\rm mph}$

# %% [markdown]
# ## Model solutions for Q2
#
#
# ### part 1
#
# To estimate the top speed of the car, we multiply the force that
#   the engine must exert by the maximum velocity $v$.  This must equal
#   to maximum power output of the engine $\dot{W}$.  Note that this
#   force will equal the sum of the drag and rolling friction.
# \begin{align*}
# \dot{W} &= F v
# \\
# &= (F_r + F_d) v
# \\
# &= \left[\mu_r mg + (C_d A) \frac{\rho v^2}{2}\right] v
# \end{align*}
# Note that this is a cubic equation; while it can be solved
# analytically, it is easier to solve it numerically.  Therefore, we
# find $v=88.5$\,m\,s$^{-1}$ or $198$\,mph.

# %%
from numpy import *
from scipy.optimize import fsolve


def res(v):
    f = (mur*m*g + Cd*A*rho*v**2/2.0)*v - W
    return f



m = 1450.0         # mass of car
Cd = 0.34
A = 2.03           # area of car / m^2
W = 745.7 * 410.0  # engine power / W
rho = 1.225        # density of air / kg m^{-3}
g = 9.81           # acceleration due to gravity / m s^{-2}
mur = 0.03         # coefficient of rolling friction


vmax = fsolve(res, 0.0)
print(vmax, vmax * 2.23694)
# Out:
# [86.01495736] [192.41029873]

# %% [markdown]
# ### part 2
#
# Substituting our expressions for the forces supplied by the engine and
# the rolling friction, we find
# \begin{align*}
# \frac{d}{dt}(mv)
# &= \frac{\dot{W}}{v} - \mu_r m g - \frac{1}{2}C_d A\rho v^2
# \\
# dt &= \frac{m}{\dot{W}/v - \mu_r m g  - \frac{1}{2}C_d A\rho v^2}  dv
# \\
# &= \frac{m v/\dot{W}}{1 - \mu_r m g v/\dot{W} - \frac{1}{2}C_d A\rho v^3/\dot{W}}  dv
# .
# \end{align*}
# If we assume that the car is stationary at time $t=0$, then we can
# integrate both sides of the equation to give a the time at which the
# car will achieve a particular speed $v$:
# \begin{align*}
# \int_0^t dt
# &= \int_0^v
# \frac{m v/\dot{W}dv}{1 - \mu_r m g v/\dot{W} - \frac{1}{2}C_d A\rho v^3/\dot{W}}
# .
# \end{align*}
# In principle, this integral could be performed analytically by determining the roots of the cubic polynomial in the denominator and using partial fractions; however, this would be quite difficult and prone to error.
#
# Instead, it is much simpler to evaluate this integral numerically using the trapezoid rule.

# %%
v_f = 60.0 / 2.23694   # final speed / m s^{-1}


def I_f(v):
    f = m*v/W/(1.0 - (mur*m*g+Cd*A*rho*v**2/2.0)*v/W)
    return f


N = 100+1
v_data = linspace(0.0, v_f, N)

I = 0.0
for k in range(N-1):
    va = v_data[k]
    vb = v_data[k+1]
    I += 0.5*(vb-va)*(I_f(va)+I_f(vb))

t = I
#print(I)

print(f'time = {t} s')
# Out:
# time = 1.7695811665948116 s

# %% [markdown]
# We find $t=1.77\,{\rm s}$, which is about a factor of two
# shorter than the actual time of $3.7\,{\rm s}$.  This is most likely due to
# the fact that we are neglecting the time it takes the engine to reach
# full power (as well as the variation of power with speed).
#
# Note that we could have also used the `quad` function from scipy.integrate to perform the integral.

# %%
from scipy.integrate import quad

I = quad(I_f, 0.0, v_f)
t = I[0]
#print(I)

print(f'time = {t} s')

# %% [markdown]
# ## Question 3
#
# Evaluate the following integrals analytically (possibly with help from an integral table) and using sympy:
#
# 1. $\displaystyle
# \int \frac{dx}{\sqrt{2-3x}}
# $
#
# 2. $\displaystyle
# \int \frac{dx}{\sqrt{3x^2-2}}
# $
#
# 3. $\displaystyle
# \int \frac{dx}{x^2\sqrt{x^2-2}}
# $
#
# 4. $\displaystyle
# \int dx\,\sqrt{x^2-2}
# $
#
# 5. $\displaystyle
# \int \frac{dx}{x^2+4x+3}
# $
#
# 6. $\displaystyle
# \int \frac{dx}{\sqrt{7+6x-x^2}}
# $
#
# 7. $\displaystyle
# \int dx\,\frac{2x+6}{\sqrt{5-4x-x^2}}
# $
#
# 8. $\displaystyle
# \int dx\,\frac{3x-5}{\sqrt{4x^2-12x}}
# $
#
# 9. $\displaystyle
# \int dx\,x^2 e^{-x}
# $
#
# 10. $\displaystyle
# \int dx\,x^2\cos(3x)
# $

# %% [markdown]
# ## Model solution for Q3

# %% [markdown]
# ### part 1
#
# Making the substitution $y=2-3x$, we find $x=(2-y)/3$,  $dx=-dy/3$,
# and
# \begin{align*}
# \int \frac{dx}{\sqrt{2-3x}}
# &= \int \frac{-dy/3}{y^{1/2}}
# = - \frac{2}{3} y ^{1/2} + C
# \end{align*}
# Re-expressing this in terms of the variable $x$, we find
# \begin{align*}
# \int \frac{dx}{\sqrt{2-3x}}
# = - \frac{2}{3} \sqrt{2-3x} + C
# \end{align*}

# %%
from sympy import *

x = symbols('x')


I = integrate(1/sqrt(2-3*x), x)
print(I)
# Out:
# -2*sqrt(2 - 3*x)/3

# %% [markdown]
# ### part 2
#
# The form of the integrand suggests a trigonometric substitution.  If
# we set
# \begin{align*}
#   x
#   &= \frac{\sqrt{2/3}}{\cos\theta}
#   \\
#   dx
#   &= \frac{\sqrt{2/3}}{\cos^2\theta}\sin\theta d\theta
#     = \sqrt{2/3}\frac{\sin\theta d\theta}{\cos^2\theta}
#        .
# \end{align*}
# We then find
# \begin{align*}
#   \int \frac{dx}{\sqrt{3x^2-2}}
#   &= \int \sqrt{2/3}\frac{\sin\theta d\theta}{\cos^2\theta}
#     \frac{1}{\sqrt{2/\cos^2\theta-2}}
#   \\
#   &= \frac{1}{\sqrt{3}}\int \frac{\sin\theta d\theta}{\cos^2\theta}
#     \frac{\cos\theta}{\sqrt{1-\cos^2\theta}}
#   \\
#   &= \frac{1}{\sqrt{3}} \int \frac{d\theta}{\cos\theta}
#     = \frac{1}{\sqrt{3}} \int \frac{\cos\theta d\theta}{\cos^2\theta}
#     = \frac{1}{\sqrt{3}} \int \frac{\cos\theta d\theta}{1-\sin^2\theta}
#   \\
#   &= \frac{1}{\sqrt{3}} \int \cos\theta\,d\theta\,
#     \frac{1}{2}
#     \Bigg[
#     \frac{1}{1+\sin\theta} + \frac{1}{1-\sin\theta}
#     \Bigg]
#   \\
#   &= \frac{1}{2\sqrt{3}}
#     \Bigg[\ln(1+\sin\theta) - \ln(1-\sin\theta)
#     \Bigg] + C'
#   \\
#    &= \frac{1}{2\sqrt{3}}\ln\frac{1+\sin\theta}{1-\sin\theta} +C'
#   \\
#   &= \frac{1}{2\sqrt{3}}\ln\frac{(1+\sin\theta)^2}{1-\sin^2\theta} +C'
#     = \frac{1}{2\sqrt{3}}\ln\frac{(1+\sin\theta)^2}{\cos^2\theta} +C
#   \\
#   &= \frac{1}{2\sqrt{3}}\ln\frac{[1+\sqrt{1-2/(3x^2)}]^2}{2/(3x^2)}
#     +C'
#   \\
#   &= \frac{1}{2\sqrt{3}}\ln\frac{[3x+\sqrt{9x^2-6}]^2}{6}
#     +C'
#   \\
#   &= \frac{1}{\sqrt{3}}\ln(3x+\sqrt{9x^2-6})
#     + C
# \end{align*}

# %%
I = integrate(1/sqrt(3*x**2-2), x)
print(I)
# Out:
# sqrt(3)*acosh(sqrt(6)*x/2)/3

# %% [markdown]
# ### part 3
#
# The form of the integrand suggests a trigonometric substitution.  If
# we set $x=\sqrt{2}/\cos\theta$, then
# \begin{align*}
#   dx
#   &= \frac{\sqrt{2}}{\cos^2\theta}\sin\theta d\theta
#     = \sqrt{2}\frac{\sin\theta d\theta}{\cos^2\theta}
#        .
# \end{align*}
# We then find
# \begin{align*}
#   \int \frac{dx}{x^2\sqrt{x^2-2}}
#   &= \int \sqrt{2}\frac{\sin\theta d\theta}{\cos^2\theta}\,
#     \frac{1}{2/\cos^2\theta}\frac{1}{\sqrt{2/\cos^2\theta-2}}
#   \\
#     &= \frac{1}{2}\int \frac{\sin\theta d\theta}{\sqrt{1/\cos^2\theta-1}}
#   \\
#   &= \frac{1}{2}\int
#     \frac{\cos\theta\sin\theta d\theta}{\sqrt{1-\cos^2\theta}}
#     = \frac{1}{2}\int\cos\theta d\theta
#   \\
#   &= \frac{1}{2}\sin\theta + C
#     = \frac{1}{2}\sqrt{1-\cos^2\theta} + C
#   \\
#   &= \frac{1}{2}\sqrt{1-2/x^2} + C
#   \\
#   &= \frac{\sqrt{x^2-2}}{2x} + C
# \end{align*}

# %%
I = integrate(1/x**2/sqrt(x**2-2), x)
print(I)

# %% [markdown]
# ### part 4
#
# $\displaystyle
# \int dx\,\sqrt{x^2-2}
# =   \frac{x}{2}\sqrt{x^2-2} - \ln(2x+2\sqrt{x^2-2})
#   + C
# $

# %%
I = integrate(sqrt(x**2-2), x)
print(I)

# %% [markdown]
# ### part 5
#
# This integral can be performed with the help of a partial fractions decomposition of the integrand.  We note that the denominator can be factored as
# \begin{align*}
# x^2+4x+3 = (x+3)(x+1).
# \end{align*}
# This allows us to decompose the integrand as
# \begin{align*}
# \frac{1}{x^2+4x+3}
# = \frac{1}{2}\Bigg[\frac{1}{x+1} - \frac{1}{x+3}\Bigg]
# \end{align*}
#
# \begin{align*}
# \int \frac{dx}{x^2+4x+3}
# &= \int \frac{1}{2}\Bigg[\frac{1}{x+1} - \frac{1}{x+3}\Bigg]
# \\
# &= \frac{1}{2} \Bigg[\ln(x+1) - \ln(x+3)\Bigg] + C
# \\
# &= \frac{1}{2}\ln\frac{x+1}{x+3} + C
# \end{align*}

# %%
I = integrate(1/(x**2+4*x+3), x)
print(I)

# %% [markdown]
# ### part 6
#
# First we complete the square in the argument of the square root:
# \begin{align*}
#   7+6x-x^2
#   &= 16-9+6x-x^2 = 16 - (x-3)^2
# \end{align*}
# This suggests the substitution:
# \begin{align*}
#   x &= 3 + 4 \sin\theta
#   \\
#   dx &= 4\cos\theta d\theta
# \end{align*}
# We then find
# \begin{align*}
#   \int \frac{dx}{\sqrt{7+6x-x^2}}
#   &= \int \frac{4\cos\theta d\theta}{\sqrt{16 - 16\sin^2\theta}}
#   \\
#   &= \int \frac{\cos\theta d\theta}{\sqrt{1-\sin^2\theta}}
#     = \int d\theta
#   \\
#   &= \theta + C
#   \\
#   &= \arcsin\frac{x-3}{4} + C
# \end{align*}

# %%
I = integrate(1/sqrt(7+6*x-x**2), x)
print(I)
# Out:
# Integral(1/sqrt(-x**2 + 6*x + 7), x)

# %% [markdown]
# ### part 7
#
# First we complete the square in the argument of the square root:
# \begin{align*}
#   5-4x-x^2
#   &= 9-4-4x-x^2 = 3^2 - (x+2)^2
# \end{align*}
# This suggests the substitution:
# \begin{align*}
#   x &= -2 + 3 \sin\theta
#   \\
#   dx &= 3\cos\theta d\theta
# \end{align*}
# We then find
# \begin{align*}
#   \int dx\,\frac{2x+6}{\sqrt{5-4x-x^2}}
#   &= \int 3\cos\theta\,d\theta\,
#     \frac{2(-2 + 3 \sin\theta)+6}{\sqrt{9-9\sin^2\theta}}
#   \\
#   &= \int d\theta\,(2+6 \sin\theta)
#   = 2\theta-6 \cos\theta + C
#   \\
#   &= 2\arcsin\frac{x+2}{3} - 6\sqrt{1-(x+2)^2/9}  + C
#   \\
#   &= 2\arcsin\frac{x+2}{3} - 2\sqrt{9-(x+2)^2}  + C
#   \\
#   &= 2\arcsin\frac{x+2}{3} - 2\sqrt{5-4x-x^2}  + C
# \end{align*}

# %%
I = integrate((2*x+6)/sqrt(5-4*x-x**2), x)
print(I)

# %% [markdown]
# ### part 8
#
# First we complete the square in the argument of the square root:
# \begin{align*}
#   4x^2-12x
#   &= 4(x^2-3x) = 4(x^2-3x+ 9/4 - 9/4)
#     = 4[(x-3/2)^2-9/4]
# \end{align*}
# This suggests the substitution:
# \begin{align*}
#   x &= \frac{3}{2} + \frac{3}{2\cos\theta}
#   \\
#   dx &= \frac{3}{2\cos^2\theta} \sin\theta d\theta
# \end{align*}
# We then find
# \begin{align*}
#   \int dx\,\frac{3x-5}{\sqrt{4x^2-12x}}
#   &= \int \frac{3\sin\theta d\theta}{2\cos^2\theta} \,
#     \frac{3x-5}{\sqrt{4[9/(4\cos^2\theta)-9/4]}}
#   \\
#   &= \frac{1}{2}\int \frac{\sin\theta d\theta}{\cos^2\theta} \,
#     \frac{(3x-5)\cos\theta}{\sqrt{1-\cos^2\theta}}
#   \\
#   &= \frac{1}{2}\int d\theta\frac{3x-5}{\cos\theta}
#   \\
#   &= \frac{1}{2}\int d\theta\frac{9(1+1/\cos\theta)/2-5}{\cos\theta}
#   \\
#   &= \frac{1}{4}\int d\theta
#     \left[\frac{9}{\cos^2\theta}- \frac{1}{\cos\theta}\right]
#   \\
#   &= \frac{1}{4}\int d\theta
#     \left[\frac{9}{\cos^2\theta}- \frac{\cos\theta}{\cos^2\theta}\right]
#   \\
#   &= \frac{1}{4}\int d\theta
#     \left[\frac{9}{\cos^2\theta}- \frac{\cos\theta}{1-\sin^2\theta}\right]
#   \\
#   &= \frac{1}{4}\int d\theta
#     \left[\frac{9}{\cos^2\theta}
#     - \frac{\cos\theta}{2(1+\sin\theta)}
#         - \frac{\cos\theta}{2(1-\sin\theta)}
#     \right]
#   \\
#   &= \frac{1}{4}
#     \left[9\tan\theta - \frac{1}{2}\ln\frac{1+\sin\theta}{1-\sin\theta}\right]
#     + C'
#   \\
#   &= \frac{1}{4}
#     \left[9\tan\theta - \frac{1}{2}\ln\frac{(1+\sin\theta)^2}{\cos^2\theta}\right]
#     + C'
#   \\
#   &= \frac{1}{4}
#     \left[9\tan\theta - \ln(1/\cos\theta+\tan\theta)\right]
#     + C'
#   \\
#   &= \frac{1}{4}
#     \left[9\sqrt{(2x/3-1)^2-1}
#     - \ln((2x/3-1)+\sqrt{(2x/3-1)^2-1})\right]
#     + C'
#   \\
#   &= \frac{3}{4}\sqrt{4x^2-12x}
#     - \frac{1}{4}\ln(2x-3+\sqrt{4x^2-12x})
#     + C
# \end{align*}

# %%
I = integrate((3*x-5)/sqrt(4*x**2-12*x), x)
print(I)

# %% [markdown]
# ### part 9
#
# This integral can be performed by repeatedly applying integration by
# parts:
# \begin{align*}
# x^2 e^{-x}
# &= \frac{d}{dx}[-x^2 e^{-x}]
# + 2 x e^{-x}
# \\
# &= \frac{d}{dx}[-x^2 e^{-x}]
# + \frac{d}{dx}[- 2 x e^{-x}]
# + 2 e^{-x}
# \\
# &= \frac{d}{dx}[-x^2 e^{-x}]
# + \frac{d}{dx}[- 2 x e^{-x}]
# + \frac{d}{dx}[- 2 e^{-x}]
# \\
# &= \frac{d}{dx}[-x^2 e^{-x} - 2 x e^{-x} - 2 e^{-x}]
# \end{align*}
# Therefore, we find
# \begin{align*}
# \int dx\,x^2 e^{-x}
# &= \int dx\,\frac{d}{dx}[-x^2 e^{-x} - 2 x e^{-x} - 2 e^{-x}]
# \\
# &= -(x^2 + 2 x + 2) e^{-x} + C
# \end{align*}

# %%
I = integrate(x**2*exp(-x), x)
print(I)

# %% [markdown]
# ### part 10
#
# This integral can be performed by repeated application of integration by parts:
# \begin{align*}
# \int dx\,x^2\cos(3x)
# &= \int dx\,\Bigg[\frac{d}{dx}\Bigg(\frac{1}{3}x^2\sin(3x)\Bigg) \
# - \frac{2}{3}x\sin(3x)\Bigg]
# \\
# &= \int dx\,\Bigg[\frac{d}{dx}\Bigg(\frac{1}{3}x^2\sin(3x)\Bigg) \
# + \frac{d}{dx}\Bigg(\frac{2}{9}x\cos(3x)\Bigg)
# - \frac{2}{9}\cos(3x)
# \Bigg]
# \\
# &= \frac{1}{3}x^2\sin(3x)
# + \frac{2}{9}x\cos(3x)
# - \frac{2}{27} \sin(3x)
# \\
# &= \frac{9x^2-2}{27}  \sin(3x)
# + \frac{6x}{27}  \cos(3x) + C
# \end{align*}

# %%
I = integrate(x**2*cos(3*x), x)
print(I)
